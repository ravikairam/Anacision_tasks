# %%
import pandas as pd

# %%
df_flight = pd.read_csv("flights.csv")

# %%
df_flight
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
set(list(df_flight["carrier"]))
# Out:
# {'9E',
#  'AA',
#  'AS',
#  'B6',
#  'DL',
#  'EV',
#  'F9',
#  'FL',
#  'HA',
#  'MQ',
#  'OO',
#  'UA',
#  'US',
#  'VX',
#  'WN',
#  'YV'}

# %%
df_flight[df_flight["arr_delay"] == 0.0]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 35      2013      1    1     627.0             630       -3.0    1018.0
# 114     2013      1    1     807.0             810       -3.0    1043.0
# 217     2013      1    1     956.0            1000       -4.0    1241.0
# 273     2013      1    1    1124.0            1125       -1.0    1445.0
# 317     2013      1    1    1219.0            1220       -1.0    1415.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336296  2013      9   30    1409.0            1415       -6.0    1550.0
# 336383  2013      9   30    1530.0            1530        0.0    1845.0
# 336438  2013      9   30    1615.0            1620       -5.0    1828.0
# 336491  2013      9   30    1703.0            1645       18.0    1915.0
# 336595  2013      9   30    1843.0            1830       13.0    1950.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_flight.dropna()
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_flight
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_clean = df_flight.dropna()

# %%
df_clean
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_clean.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  327346.0  327346.000000  327346.000000  327346.000000   327346.000000
# mean     2013.0       6.564803      15.740825    1348.789883     1340.335098
# std         0.0       3.413444       8.777376     488.319979      467.413156
# min      2013.0       1.000000       1.000000       1.000000      500.000000
# 25%      2013.0       4.000000       8.000000     907.000000      905.000000
# 50%      2013.0       7.000000      16.000000    1400.000000     1355.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  327346.000000  327346.000000   327346.000000  327346.000000
# mean       12.555156    1501.908238     1532.788426       6.895377
# std        40.065688     532.888731      497.979124      44.633292
# ...

# %%
df_clean.plot(x='flight', y='dep_delay', style='o')
# Out:
# <AxesSubplot:xlabel='flight'>

# %%
# evaluation of a model using all input features
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
X = df_clean.drop(columns=['arr_delay', 'origin', 'dest', 'flight', 'carrier', 'tailnum', 'time_hour'])
y = df_clean['arr_delay']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression()
  
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.8768382575952847

# %%
df_clean['dest'].unique()
# Out:
# array(['IAH', 'MIA', 'BQN', 'ATL', 'ORD', 'FLL', 'IAD', 'MCO', 'PBI',
#        'TPA', 'LAX', 'SFO', 'DFW', 'BOS', 'LAS', 'MSP', 'DTW', 'RSW',
#        'SJU', 'PHX', 'BWI', 'CLT', 'BUF', 'DEN', 'SNA', 'MSY', 'SLC',
#        'XNA', 'MKE', 'SEA', 'ROC', 'SYR', 'SRQ', 'RDU', 'CMH', 'JAX',
#        'CHS', 'MEM', 'PIT', 'SAN', 'DCA', 'CLE', 'STL', 'MYR', 'JAC',
#        'MDW', 'HNL', 'BNA', 'AUS', 'BTV', 'PHL', 'STT', 'EGE', 'AVL',
#        'PWM', 'IND', 'SAV', 'CAK', 'HOU', 'LGB', 'DAY', 'ALB', 'BDL',
#        'MHT', 'MSN', 'GSO', 'CVG', 'BUR', 'RIC', 'GSP', 'GRR', 'MCI',
#        'ORF', 'SAT', 'SDF', 'PDX', 'SJC', 'OMA', 'CRW', 'OAK', 'SMF',
#        'TYS', 'PVD', 'DSM', 'PSE', 'TUL', 'BHM', 'OKC', 'CAE', 'HDN',
#        'BZN', 'MTJ', 'EYW', 'PSP', 'ACK', 'BGR', 'ABQ', 'ILM', 'MVY',
#        'SBN', 'LEX', 'CHO', 'TVC', 'ANC'], dtype=object)

# %%
df_clean.plot(x='origin', y='arr_delay')
# Out:
# <AxesSubplot:xlabel='origin'>

# %%
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 reg = ensemble.GradientBoostingRegressor(**params)
# ----> 2 reg.fit(X_train, y_train)
#
# File ~/anaconda3/envs/flight-env/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:586, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     583     self._resize_state()
#     585 # fit the boosting stages
# --> 586 n_stages = self._fit_stages(
#     587     X,
#     588     y,
#     589     raw_predictions,
#     590     sample_weight,
#     591     self._rng,
#     592     X_val,
#     593     y_val,
#     594     sample_weight_val,
#     595     begin_at_stage,
#     596     monitor,
#     597 )
#     599 # change shape of arrays after fit (early-stopping or additional ests)
#     600 if n_stages != self.estimators_.shape[0]:
#
# ...

# %%
reg.score(X_test,y_test)

# %%
from sklearn.linear_model import Ridge

# %%
rid = Ridge(alpha=1.0)

# %%
rid.fit(X_train, y_train)
# Out:
# Ridge()

# %%
rid.score(X_test, y_test)
# Out:
# 0.8768382576176252

# %%
X = df_clean.drop(columns=['dep_delay', 'origin', 'dest', 'flight', 'carrier', 'tailnum', 'time_hour'])
y = df_clean['dep_delay']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
regr = LinearRegression()
  
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.8757533718770518

# %%
### For second part of question
df_clean['is_dep_delay'] = np.where(df_clean['dep_delay'] > 30.0, True, False)
# Out:
# /tmp/ipykernel_6050/3430133356.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['is_dep_delay'] = np.where(df_clean['dep_delay'] > 30.0, True, False)

# %%
df_clean
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2240.0            2245       -5.0    2334.0
# 336766  2013      9   30    2240.0            2250      -10.0    2347.0
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_clean['is_dep_delay'].unique()
# Out:
# array([False,  True])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logisticRegr = LogisticRegression()

# %%
X = df_clean.drop(columns=['dep_delay', 'origin', 'dest', 'flight', 'carrier', 'tailnum', 'time_hour', 'is_dep_delay'])
y = df_clean['is_dep_delay']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
logisticRegr = LogisticRegression(class_weight='balanced')
  
logisticRegr.fit(X_train, y_train)
score = logisticRegr.score(X_test, y_test)
print(score)
# Out:
# 0.938573017094957
# /home/arjun/anaconda3/envs/flight-env/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df_clean.groupby(['is_dep_delay']).count()
# Out:
#                 year   month     day  dep_time  sched_dep_time  dep_delay  \
# is_dep_delay
# False         279441  279441  279441    279441          279441     279441
# True           47905   47905   47905     47905           47905      47905
#
#               arr_time  sched_arr_time  arr_delay  carrier  flight  tailnum  \
# is_dep_delay
# False           279441          279441     279441   279441  279441   279441
# True             47905           47905      47905    47905   47905    47905
#
#               origin    dest  air_time  distance    hour  minute  time_hour
# is_dep_delay
# False         279441  279441    279441    279441  279441  279441     279441
# True           47905   47905     47905     47905   47905   47905      47905

# %%
df_clean['is_dep_delay'].value_counts()
# Out:
# False    279441
# True      47905
# Name: is_dep_delay, dtype: int64

# %%
pred = logisticRegr.predict(X_test)

# %%
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[65666  4203]
#  [  824 11144]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy: {0}%'.format(score*100)
plt.title(all_sample_title, size = 15);

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
precision_recall_fscore_support(y_test, pred, average='weighted')
# Out:
# (0.9493690270904008, 0.938573017094957, 0.941611341502476, None)
